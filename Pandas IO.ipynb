# %% [markdown]
# # Pandas: Formatos diferentes de entrada e saída (IO) JSON, HTML, CSV, Excel, banco SQL

# %% [markdown]
# ## Começaremos criando o nome dos alunos e alunas a partir de um arquivo JSON. Para buscarmos os nomes dos cursos, realizaremos a leitura de uma página HTML

# %%
import pandas as pd

# %%
pd.read_json("https://servicodados.ibge.gov.br/api/v1/censos/nomes/ranking?qtd=20&sexo=f")
# Out:
#          nome  regiao      freq  rank sexo
# 0       MARIA       0  11694738     1    F
# 1         ANA       0   3079729     2    F
# 2   FRANCISCA       0    721637     3    F
# 3     ANTONIA       0    588783     4    F
# 4     ADRIANA       0    565621     5    F
# 5     JULIANA       0    562589     6    F
# 6      MARCIA       0    551855     7    F
# 7    FERNANDA       0    531607     8    F
# 8    PATRICIA       0    529446     9    F
# 9       ALINE       0    509869    10    F
# 10     SANDRA       0    479230    11    F
# 11     CAMILA       0    469851    12    F
# 12     AMANDA       0    464624    13    F
# 13      BRUNA       0    460770    14    F
# 14    JESSICA       0    456472    15    F
# 15    LETICIA       0    434056    16    F
# 16      JULIA       0    430067    17    F
# 17    LUCIANA       0    429769    18    F
# 18    VANESSA       0    417512    19    F
# 19    MARIANA       0    381778    20    F

# %%
pd.read_json("https://servicodados.ibge.gov.br/api/v1/censos/nomes/ranking?qtd=20&sexo=m")
# Out:
#          nome  regiao     freq  rank sexo
# 0        JOSE       0  5732508     1    M
# 1        JOAO       0  2971935     2    M
# 2     ANTONIO       0  2567494     3    M
# 3   FRANCISCO       0  1765197     4    M
# 4      CARLOS       0  1483121     5    M
# 5       PAULO       0  1417907     6    M
# 6       PEDRO       0  1213557     7    M
# 7       LUCAS       0  1116818     8    M
# 8        LUIZ       0  1102927     9    M
# 9      MARCOS       0  1101126    10    M
# 10       LUIS       0   931530    11    M
# 11    GABRIEL       0   922744    12    M
# 12     RAFAEL       0   814709    13    M
# 13     DANIEL       0   706527    14    M
# 14    MARCELO       0   690098    15    M
# 15      BRUNO       0   663271    16    M
# 16    EDUARDO       0   628539    17    M
# 17     FELIPE       0   615924    18    M
# 18   RAIMUNDO       0   611174    19    M
# 19    RODRIGO       0   598825    20    M

# %%
pd.read_json("https://servicodados.ibge.gov.br/api/v1/censos/nomes/ranking?qtd=20&sexo=f")
# Out:
#          nome  regiao      freq  rank sexo
# 0       MARIA       0  11694738     1    F
# 1         ANA       0   3079729     2    F
# 2   FRANCISCA       0    721637     3    F
# 3     ANTONIA       0    588783     4    F
# 4     ADRIANA       0    565621     5    F
# 5     JULIANA       0    562589     6    F
# 6      MARCIA       0    551855     7    F
# 7    FERNANDA       0    531607     8    F
# 8    PATRICIA       0    529446     9    F
# 9       ALINE       0    509869    10    F
# 10     SANDRA       0    479230    11    F
# 11     CAMILA       0    469851    12    F
# 12     AMANDA       0    464624    13    F
# 13      BRUNA       0    460770    14    F
# 14    JESSICA       0    456472    15    F
# 15    LETICIA       0    434056    16    F
# 16      JULIA       0    430067    17    F
# 17    LUCIANA       0    429769    18    F
# 18    VANESSA       0    417512    19    F
# 19    MARIANA       0    381778    20    F

# %%
nomes_f = pd.read_json("https://servicodados.ibge.gov.br/api/v1/censos/nomes/ranking?qtd=20&sexo=f")
nomes_m = pd.read_json("https://servicodados.ibge.gov.br/api/v1/censos/nomes/ranking?qtd=20&sexo=m")

# %%
nomes_f
# Out:
#          nome  regiao      freq  rank sexo
# 0       MARIA       0  11694738     1    F
# 1         ANA       0   3079729     2    F
# 2   FRANCISCA       0    721637     3    F
# 3     ANTONIA       0    588783     4    F
# 4     ADRIANA       0    565621     5    F
# 5     JULIANA       0    562589     6    F
# 6      MARCIA       0    551855     7    F
# 7    FERNANDA       0    531607     8    F
# 8    PATRICIA       0    529446     9    F
# 9       ALINE       0    509869    10    F
# 10     SANDRA       0    479230    11    F
# 11     CAMILA       0    469851    12    F
# 12     AMANDA       0    464624    13    F
# 13      BRUNA       0    460770    14    F
# 14    JESSICA       0    456472    15    F
# 15    LETICIA       0    434056    16    F
# 16      JULIA       0    430067    17    F
# 17    LUCIANA       0    429769    18    F
# 18    VANESSA       0    417512    19    F
# 19    MARIANA       0    381778    20    F

# %%
nomes_m
# Out:
#          nome  regiao     freq  rank sexo
# 0        JOSE       0  5732508     1    M
# 1        JOAO       0  2971935     2    M
# 2     ANTONIO       0  2567494     3    M
# 3   FRANCISCO       0  1765197     4    M
# 4      CARLOS       0  1483121     5    M
# 5       PAULO       0  1417907     6    M
# 6       PEDRO       0  1213557     7    M
# 7       LUCAS       0  1116818     8    M
# 8        LUIZ       0  1102927     9    M
# 9      MARCOS       0  1101126    10    M
# 10       LUIS       0   931530    11    M
# 11    GABRIEL       0   922744    12    M
# 12     RAFAEL       0   814709    13    M
# 13     DANIEL       0   706527    14    M
# 14    MARCELO       0   690098    15    M
# 15      BRUNO       0   663271    16    M
# 16    EDUARDO       0   628539    17    M
# 17     FELIPE       0   615924    18    M
# 18   RAIMUNDO       0   611174    19    M
# 19    RODRIGO       0   598825    20    M

# %%
nomes_f = pd.read_json("https://servicodados.ibge.gov.br/api/v1/censos/nomes/ranking?qtd=200&sexo=f")
nomes_m = pd.read_json("https://servicodados.ibge.gov.br/api/v1/censos/nomes/ranking?qtd=200&sexo=m")

# %%
nomes_m.head()
# Out:
#         nome  regiao     freq  rank sexo
# 0       JOSE       0  5732508     1    M
# 1       JOAO       0  2971935     2    M
# 2    ANTONIO       0  2567494     3    M
# 3  FRANCISCO       0  1765197     4    M
# 4     CARLOS       0  1483121     5    M

# %%
nomes_f.head()
# Out:
#         nome  regiao      freq  rank sexo
# 0      MARIA       0  11694738     1    F
# 1        ANA       0   3079729     2    F
# 2  FRANCISCA       0    721637     3    F
# 3    ANTONIA       0    588783     4    F
# 4    ADRIANA       0    565621     5    F

# %%
print("Quantidade de nomes: " + str(len(nomes_f) + len(nomes_m)))
# Out:
# Quantidade de nomes: 400

# %%
frames = [nomes_f, nomes_m]

# %%
frames
# Out:
# [          nome  regiao      freq  rank sexo
#  0        MARIA       0  11694738     1    F
#  1          ANA       0   3079729     2    F
#  2    FRANCISCA       0    721637     3    F
#  3      ANTONIA       0    588783     4    F
#  4      ADRIANA       0    565621     5    F
#  ..         ...     ...       ...   ...  ...
#  195     ROSANE       0     82203   196    F
#  196    IVONETE       0     81878   197    F
#  197    LUCIANE       0     81230   198    F
#  198    ISADORA       0     81100   199    F
#  199      NILZA       0     80128   200    F
#
#  [200 rows x 5 columns],
#            nome  regiao     freq  rank sexo
#  0         JOSE       0  5732508     1    M
#  1         JOAO       0  2971935     2    M
#  2      ANTONIO       0  2567494     3    M
#  3    FRANCISCO       0  1765197     4    M
#  4       CARLOS       0  1483121     5    M
#  ..         ...     ...      ...   ...  ...
#  195     WALTER       0    67207   196    M
# ...

# %%
pd.concat(frames)['nome'].to_frame()
# Out:
#           nome
# 0        MARIA
# 1          ANA
# 2    FRANCISCA
# 3      ANTONIA
# 4      ADRIANA
# ..         ...
# 195     WALTER
# 196    ARLINDO
# 197    MICHAEL
# 198     ALVARO
# 199    GEOVANE
#
# [400 rows x 1 columns]

# %%
nomes = pd.concat(frames)['nome'].to_frame()
nomes
# Out:
#           nome
# 0        MARIA
# 1          ANA
# 2    FRANCISCA
# 3      ANTONIA
# 4      ADRIANA
# ..         ...
# 195     WALTER
# 196    ARLINDO
# 197    MICHAEL
# 198     ALVARO
# 199    GEOVANE
#
# [400 rows x 1 columns]

# %%
nomes.sample(6)
# Out:
#            nome
# 184     MARILIA
# 126  SEBASTIANA
# 1          JOAO
# 118      SANDRO
# 5         PAULO
# 43    TEREZINHA

# %%
nomes.sample(6)
# Out:
#           nome
# 97     OSVALDO
# 185    JONATAN
# 142     RAISSA
# 40   APARECIDA
# 184     ALISON
# 188    POLIANA

# %% [markdown]
# # Criando os nomes

# %% [markdown]
# # Incluindo ID dos alunos

# %%
import numpy as np

# %%
import numpy as np
np.random.seed(123)

# %%
total_alunos = len(nomes)
total_alunos
# Out:
# 400

# %%
nomes.sample(3)
# Out:
#           nome
# 34   SEBASTIAO
# 42     MARLENE
# 103     MAICON

# %%
nomes["id_aluno"] =  np.random.permutation(total_alunos) + 1
nomes
# Out:
#           nome  id_aluno
# 0        MARIA       189
# 1          ANA        58
# 2    FRANCISCA       204
# 3      ANTONIA       383
# 4      ADRIANA       231
# ..         ...       ...
# 195     WALTER         9
# 196    ARLINDO       378
# 197    MICHAEL        50
# 198     ALVARO       244
# 199    GEOVANE       387
#
# [400 rows x 2 columns]

# %%
nomes.sample(5)
# Out:
#         nome  id_aluno
# 46   FABIANA       373
# 159    SELMA        29
# 3    ANTONIA       383
# 97   BARBARA        71
# 64    ROBSON       188

# %%
dominios = ['@dominiodoemmail.com.br', '@servicodoemail.com']
dominios
# Out:
# ['@dominiodoemmail.com.br', '@servicodoemail.com']

# %%
dominios = ['@dominiodoemmail.com.br', '@servicodoemail.com']
nomes['dominio'] = np.random.choice(dominios, total_alunos)

# %%
nomes.sample(5)
# Out:
#          nome  id_aluno                  dominio
# 190  NATANAEL        72      @servicodoemail.com
# 104  REINALDO       351      @servicodoemail.com
# 193  LUCILENE       120      @servicodoemail.com
# 98      THAIS        12  @dominiodoemmail.com.br
# 2     ANTONIO       122  @dominiodoemmail.com.br

# %%
nomes['email'] = nomes.nome.str.cat(nomes.dominio).str.lower()
nomes
# Out:
#           nome  id_aluno                  dominio  \
# 0        MARIA       189      @servicodoemail.com
# 1          ANA        58      @servicodoemail.com
# 2    FRANCISCA       204  @dominiodoemmail.com.br
# 3      ANTONIA       383  @dominiodoemmail.com.br
# 4      ADRIANA       231  @dominiodoemmail.com.br
# ..         ...       ...                      ...
# 195     WALTER         9      @servicodoemail.com
# 196    ARLINDO       378  @dominiodoemmail.com.br
# 197    MICHAEL        50  @dominiodoemmail.com.br
# 198     ALVARO       244      @servicodoemail.com
# 199    GEOVANE       387  @dominiodoemmail.com.br
#
#                                 email
# 0            maria@servicodoemail.com
# 1              ana@servicodoemail.com
# 2    francisca@dominiodoemmail.com.br
# 3      antonia@dominiodoemmail.com.br
# 4      adriana@dominiodoemmail.com.br
# ..                                ...
# 195         walter@servicodoemail.com
# 196    arlindo@dominiodoemmail.com.br
# ...

# %% [markdown]
# ## Criando cursos

# %%
## Instalando as bibliotecas necessárias para o projeto

# %%
# !pip3 install html5lib
# !pip3 install lxml

# %%
import html5lib

# %%
url = 'http://tabela-cursos.herokuapp.com/index.html'
cursos = pd.read_html(url)
cursos
# Out:
# [                          Nome do curso
#  0                 Lógica de programação
#  1                         Java para Web
#  2                           C# para Web
#  3                         Ruby on Rails
#  4                      Cursos de Python
#  5                         PHP com MySql
#  6                         .NET para web
#  7            Novas integrações com Java
#  8                          TDD com Java
#  9                   Código limpo com C#
#  10  Preparatório para certificação Java
#  11                      Hardware básico
#  12                Persistência com .NET
#  13                  Desenvolvendo jogos
#  14                     Análise de dados
#  15                   Estatística básica
#  16                  Internet das coisas
#  17                Programação funcional
#  18                Boas práticas em Java
#  19          Orientação objetos com Java]

# %%
type(cursos)
# Out:
# list

# %%
cursos = cursos[0]

# %%
type(cursos)
# Out:
# pandas.core.frame.DataFrame

# %%
cursos
# Out:
#                           Nome do curso
# 0                 Lógica de programação
# 1                         Java para Web
# 2                           C# para Web
# 3                         Ruby on Rails
# 4                      Cursos de Python
# 5                         PHP com MySql
# 6                         .NET para web
# 7            Novas integrações com Java
# 8                          TDD com Java
# 9                   Código limpo com C#
# 10  Preparatório para certificação Java
# 11                      Hardware básico
# 12                Persistência com .NET
# 13                  Desenvolvendo jogos
# 14                     Análise de dados
# 15                   Estatística básica
# 16                  Internet das coisas
# 17                Programação funcional
# 18                Boas práticas em Java
# 19          Orientação objetos com Java

# %%
cursos.head()
# Out:
#            Nome do curso
# 0  Lógica de programação
# 1          Java para Web
# 2            C# para Web
# 3          Ruby on Rails
# 4       Cursos de Python

# %%
cursos = cursos.rename(columns={'Nome do curso': 'nome_do_curso'})
cursos.head(2)
# Out:
#            nome_do_curso
# 0  Lógica de programação
# 1          Java para Web

# %%
cursos['id'] = cursos.index + 1
cursos.head()
# Out:
#            nome_do_curso  id
# 0  Lógica de programação   1
# 1          Java para Web   2
# 2            C# para Web   3
# 3          Ruby on Rails   4
# 4       Cursos de Python   5

# %%
cursos = cursos.set_index('id')
cursos.head()
# Out:
#             nome_do_curso
# id
# 1   Lógica de programação
# 2           Java para Web
# 3             C# para Web
# 4           Ruby on Rails
# 5        Cursos de Python

# %% [markdown]
# ## Matriculando os alunos nos cursos

# %%
##Criaremos uma nova coluna nomes['matriculas'] que receberá a chamada de np.random.exponential()

# %%
nomes['matriculas'] = np.random.exponential(size=total_alunos).astype(int)
nomes.sample(5)
# Out:
#           nome  id_aluno                  dominio  \
# 23    FERNANDO       134      @servicodoemail.com
# 169     JOELMA       167      @servicodoemail.com
# 148  APARECIDO        73      @servicodoemail.com
# 24     CLAUDIA       109  @dominiodoemmail.com.br
# 105     MILENA       245      @servicodoemail.com
#
#                               email  matriculas
# 23      fernando@servicodoemail.com           0
# 169       joelma@servicodoemail.com           0
# 148    aparecido@servicodoemail.com           0
# 24   claudia@dominiodoemmail.com.br           1
# 105       milena@servicodoemail.com           0

# %%
nomes['matriculas'] = np.ceil(np.random.exponential(size=total_alunos)).astype(int)
nomes.sample(5)
# Out:
#         nome  id_aluno                  dominio  \
# 63    MIGUEL        81  @dominiodoemmail.com.br
# 97   BARBARA        71  @dominiodoemmail.com.br
# 20    MANOEL       218      @servicodoemail.com
# 172   REBECA       281      @servicodoemail.com
# 10      LUIS       152  @dominiodoemmail.com.br
#
#                               email  matriculas
# 63    miguel@dominiodoemmail.com.br           1
# 97   barbara@dominiodoemmail.com.br           1
# 20        manoel@servicodoemail.com           1
# 172       rebeca@servicodoemail.com           2
# 10      luis@dominiodoemmail.com.br           1

# %% [markdown]
# ## Aumentar o número de cursos nos quais os alunos e alunas estão matriculados

# %%
nomes['matriculas'] = np.ceil(np.random.exponential(size=total_alunos) * 1.5).astype(int)
nomes.sample(5)
# Out:
#          nome  id_aluno                  dominio  \
# 67   HENRIQUE       386      @servicodoemail.com
# 102  MARILENE        68      @servicodoemail.com
# 49       ALEX       308      @servicodoemail.com
# 8    PATRICIA         5  @dominiodoemmail.com.br
# 89       JEAN       342  @dominiodoemmail.com.br
#
#                                email  matriculas
# 67       henrique@servicodoemail.com           4
# 102      marilene@servicodoemail.com           1
# 49           alex@servicodoemail.com           1
# 8    patricia@dominiodoemmail.com.br           5
# 89       jean@dominiodoemmail.com.br           2

# %%
nomes.matriculas.describe()
# Out:
# count    400.000000
# mean       2.030000
# std        1.493209
# min        1.000000
# 25%        1.000000
# 50%        2.000000
# 75%        3.000000
# max       13.000000
# Name: matriculas, dtype: float64

# %%
##Para visualizarmos as informações em um gráfico, importaremos a biblioteca seaborn

# %%
import seaborn as sns

# %%
sns.distplot(nomes.matriculas)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='matriculas', ylabel='Density'>

# %%
##Como esperávamos, temos muitos alunos inscritos em um curso, menos inscritos em 2, 
##menos ainda em 3 e assim por diante. Passaremos para uma visualização do número exato 
##de alunos com cada quantidade de matrículas, que conseguiremos a partir da função value_counts()

# %%
nomes.matriculas.value_counts()
# Out:
# 1     198
# 2     101
# 3      50
# 4      23
# 5      16
# 8       5
# 6       5
# 13      1
# 7       1
# Name: matriculas, dtype: int64

# %%
nomes.sample(5)
# Out:
#          nome  id_aluno                  dominio  \
# 189     DALVA       240  @dominiodoemmail.com.br
# 18   RAIMUNDO       267      @servicodoemail.com
# 8    PATRICIA         5  @dominiodoemmail.com.br
# 3     ANTONIA       383  @dominiodoemmail.com.br
# 57     DAIANE       178  @dominiodoemmail.com.br
#
#                                email  matriculas
# 189     dalva@dominiodoemmail.com.br           2
# 18       raimundo@servicodoemail.com           1
# 8    patricia@dominiodoemmail.com.br           5
# 3     antonia@dominiodoemmail.com.br           1
# 57     daiane@dominiodoemmail.com.br           1

# %% [markdown]
# ## Selecionando cursos

# %%
todas_matriculas = []
x = np.random.rand(20)
prob = x / sum(x)

# %%
for index, row in nomes.iterrows():
  id = row.id_aluno
  matriculas = row.matriculas
  for i in range(matriculas):
    mat = [id, np.random.choice(cursos.index, p = prob)]

# %%
for index, row in nomes.iterrows():
  id = row.id_aluno
  matriculas = row.matriculas
  for i in range(matriculas):
    mat = [id, np.random.choice(cursos.index, p = prob)]
    todas_matriculas.append(mat)

matriculas = pd.DataFrame(todas_matriculas, columns = ['id_aluno', 'id_curso'])
matriculas.head(5)
# Out:
#    id_aluno  id_curso
# 0       189        15
# 1       189         6
# 2       189        10
# 3        58        10
# 4        58         5

# %%
matriculas.groupby('id_curso').count().join(cursos['nome_do_curso'])
# Out:
#           id_aluno                        nome_do_curso
# id_curso
# 1               50                Lógica de programação
# 2               30                        Java para Web
# 3               12                          C# para Web
# 4                6                        Ruby on Rails
# 5               42                     Cursos de Python
# 6               29                        PHP com MySql
# 7               65                        .NET para web
# 8               45           Novas integrações com Java
# 9                2                         TDD com Java
# 10              61                  Código limpo com C#
# 11              55  Preparatório para certificação Java
# 12              74                      Hardware básico
# 13              22                Persistência com .NET
# 14              80                  Desenvolvendo jogos
# 15              95                     Análise de dados
# 16              45                   Estatística básica
# ...

# %%
matriculas.groupby('id_curso').count().join(cursos['nome_do_curso']).rename(columns={'id_aluno':'quantidade_de_alunos'})
# Out:
#           quantidade_de_alunos                        nome_do_curso
# id_curso
# 1                           50                Lógica de programação
# 2                           30                        Java para Web
# 3                           12                          C# para Web
# 4                            6                        Ruby on Rails
# 5                           42                     Cursos de Python
# 6                           29                        PHP com MySql
# 7                           65                        .NET para web
# 8                           45           Novas integrações com Java
# 9                            2                         TDD com Java
# 10                          61                  Código limpo com C#
# 11                          55  Preparatório para certificação Java
# 12                          74                      Hardware básico
# 13                          22                Persistência com .NET
# ...

# %%
nomes.sample(5)
# Out:
#         nome  id_aluno                  dominio  \
# 192  AGNALDO       235  @dominiodoemmail.com.br
# 78    SILVIA        57  @dominiodoemmail.com.br
# 160    LEILA       390      @servicodoemail.com
# 41   DANIELA       227  @dominiodoemmail.com.br
# 106    ARTUR       293      @servicodoemail.com
#
#                               email  matriculas
# 192  agnaldo@dominiodoemmail.com.br           1
# 78    silvia@dominiodoemmail.com.br           1
# 160        leila@servicodoemail.com           4
# 41   daniela@dominiodoemmail.com.br           2
# 106        artur@servicodoemail.com           1

# %%
cursos.head(10)
# Out:
#                  nome_do_curso
# id
# 1        Lógica de programação
# 2                Java para Web
# 3                  C# para Web
# 4                Ruby on Rails
# 5             Cursos de Python
# 6                PHP com MySql
# 7                .NET para web
# 8   Novas integrações com Java
# 9                 TDD com Java
# 10         Código limpo com C#

# %%
matriculas.head(10)
# Out:
#    id_aluno  id_curso
# 0       189        15
# 1       189         6
# 2       189        10
# 3        58        10
# 4        58         5
# 5       204         7
# 6       383         5
# 7       231        15
# 8       285        11
# 9       285        14

# %%
matriculas_por_curso = matriculas.groupby('id_curso').count().join(cursos['nome_do_curso']).rename(columns={'id_aluno':'quantidade_de_alunos'})

# %%
matriculas_por_curso.head(10)
# Out:
#           quantidade_de_alunos               nome_do_curso
# id_curso
# 1                           50       Lógica de programação
# 2                           30               Java para Web
# 3                           12                 C# para Web
# 4                            6               Ruby on Rails
# 5                           42            Cursos de Python
# 6                           29               PHP com MySql
# 7                           65               .NET para web
# 8                           45  Novas integrações com Java
# 9                            2                TDD com Java
# 10                          61         Código limpo com C#

# %% [markdown]
# ## exportando o dataframe matriculas_por_curso para um novo formato como o CSV

# %%
matriculas_por_curso.to_csv('matriculas_por_curso.csv', index=False)

# %%
pd.read_csv('matriculas_por_curso.csv')
# Out:
#     quantidade_de_alunos                        nome_do_curso
# 0                     50                Lógica de programação
# 1                     30                        Java para Web
# 2                     12                          C# para Web
# 3                      6                        Ruby on Rails
# 4                     42                     Cursos de Python
# 5                     29                        PHP com MySql
# 6                     65                        .NET para web
# 7                     45           Novas integrações com Java
# 8                      2                         TDD com Java
# 9                     61                  Código limpo com C#
# 10                    55  Preparatório para certificação Java
# 11                    74                      Hardware básico
# 12                    22                Persistência com .NET
# 13                    80                  Desenvolvendo jogos
# ...

# %% [markdown]
# ## criaremos a variável matriculas_json

# %%
matriculas_json = matriculas_por_curso.to_json()
matriculas_json
# Out:
# '{"quantidade_de_alunos":{"1":50,"2":30,"3":12,"4":6,"5":42,"6":29,"7":65,"8":45,"9":2,"10":61,"11":55,"12":74,"13":22,"14":80,"15":95,"16":45,"17":81,"18":5,"19":9,"20":4},"nome_do_curso":{"1":"L\\u00f3gica de programa\\u00e7\\u00e3o","2":"Java para Web","3":"C# para Web","4":"Ruby on Rails","5":"Cursos de Python","6":"PHP com MySql","7":".NET para web","8":"Novas integra\\u00e7\\u00f5es com Java","9":"TDD com Java","10":"C\\u00f3digo limpo com C#","11":"Preparat\\u00f3rio para certifica\\u00e7\\u00e3o Java","12":"Hardware b\\u00e1sico","13":"Persist\\u00eancia com .NET","14":"Desenvolvendo jogos","15":"An\\u00e1lise de dados","16":"Estat\\u00edstica b\\u00e1sica","17":"Internet das coisas","18":"Programa\\u00e7\\u00e3o funcional","19":"Boas pr\\u00e1ticas em Java","20":"Orienta\\u00e7\\u00e3o objetos com Java"}}'

# %% [markdown]
# ## transformamos o dataframe matriculas_por_curso em HTML

# %%
matriculas_html = matriculas_por_curso.to_html()
matriculas_html
# Out:
# '<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>quantidade_de_alunos</th>\n      <th>nome_do_curso</th>\n    </tr>\n    <tr>\n      <th>id_curso</th>\n      <th></th>\n      <th></th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>1</th>\n      <td>50</td>\n      <td>Lógica de programação</td>\n    </tr>\n    <tr>\n      <th>2</th>\n      <td>30</td>\n      <td>Java para Web</td>\n    </tr>\n    <tr>\n      <th>3</th>\n      <td>12</td>\n      <td>C# para Web</td>\n    </tr>\n    <tr>\n      <th>4</th>\n      <td>6</td>\n      <td>Ruby on Rails</td>\n    </tr>\n    <tr>\n      <th>5</th>\n      <td>42</td>\n      <td>Cursos de Python</td>\n    </tr>\n    <tr>\n      <th>6</th>\n      <td>29</td>\n      <td>PHP com MySql</td>\n    </tr>\n    <tr>\n      <th>7</th>\n      <td>65</td>\n      <td>.NET para web</td>\n    </tr>\n    <tr>\n      <th>8</th>\n      <td>45</td>\n      <td>Novas integrações com Java</td>\
# ...

# %% [markdown]
# ## melhorando essa exibição

# %%
print(matriculas_html)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>quantidade_de_alunos</th>
#       <th>nome_do_curso</th>
#     </tr>
#     <tr>
#       <th>id_curso</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>50</td>
#       <td>Lógica de programação</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>30</td>
#       <td>Java para Web</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>12</td>
#       <td>C# para Web</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>6</td>
#       <td>Ruby on Rails</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>42</td>
#       <td>Cursos de Python</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>29</td>
#       <td>PHP com MySql</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>65</td>
#       <td>.NET para web</td>
#     </tr>
#     <tr>
#       <th>8</th>
# ...

# %%
##Com isso, aprendemos a exportar um dataframe para três formatos diferentes: CSV, JSON e HTML!

# %%
# !pip3 install sqlalchemy

# %%
from sqlalchemy import create_engine, MetaData, Table

# %%
engine = create_engine('sqlite:///:memory:')

# %%
type(engine)
# Out:
# sqlalchemy.engine.base.Engine

# %%
matriculas_por_curso.to_sql('matriculas', engine)

# %%
print(engine.table_names())
# Out:
# ['matriculas']
# C:\Users\Renato\AppData\Local\Temp/ipykernel_11080/224578794.py:1: SADeprecationWarning: The Engine.table_names() method is deprecated and will be removed in a future release.  Please refer to Inspector.get_table_names(). (deprecated since: 1.4)
#   print(engine.table_names())

# %%
query = 'select * from matriculas where quantidade_de_alunos < 20'

# %%
pd.read_sql(query, engine)
# Out:
#    id_curso  quantidade_de_alunos                nome_do_curso
# 0         3                    12                  C# para Web
# 1         4                     6                Ruby on Rails
# 2         9                     2                 TDD com Java
# 3        18                     5        Programação funcional
# 4        19                     9        Boas práticas em Java
# 5        20                     4  Orientação objetos com Java

# %%
query = 'select * from matriculas where quantidade_de_alunos < 30'

# %%
pd.read_sql(query, engine)
# Out:
#    id_curso  quantidade_de_alunos                nome_do_curso
# 0         3                    12                  C# para Web
# 1         4                     6                Ruby on Rails
# 2         6                    29                PHP com MySql
# 3         9                     2                 TDD com Java
# 4        13                    22        Persistência com .NET
# 5        18                     5        Programação funcional
# 6        19                     9        Boas práticas em Java
# 7        20                     4  Orientação objetos com Java

# %%
pd.read_sql_table('matriculas', engine, columns=['nome_do_curso', 'quantidade_de_alunos'])
# Out:
#                           nome_do_curso  quantidade_de_alunos
# 0                 Lógica de programação                    50
# 1                         Java para Web                    30
# 2                           C# para Web                    12
# 3                         Ruby on Rails                     6
# 4                      Cursos de Python                    42
# 5                         PHP com MySql                    29
# 6                         .NET para web                    65
# 7            Novas integrações com Java                    45
# 8                          TDD com Java                     2
# 9                   Código limpo com C#                    61
# 10  Preparatório para certificação Java                    55
# 11                      Hardware básico                    74
# 12                Persistência com .NET                    22
# 13                  Desenvolvendo jogos                    80
# ...

# %%
muitas_matriculas = pd.read_sql_table('matriculas', engine, columns=['nome_do_curso', 'quantidade_de_alunos'])

# %%
muitas_matriculas.query('quantidade_de_alunos > 60')
# Out:
#           nome_do_curso  quantidade_de_alunos
# 6         .NET para web                    65
# 9   Código limpo com C#                    61
# 11      Hardware básico                    74
# 13  Desenvolvendo jogos                    80
# 14     Análise de dados                    95
# 16  Internet das coisas                    81

# %%
muitas_matriculas = muitas_matriculas.query('quantidade_de_alunos > 80')
muitas_matriculas
# Out:
#           nome_do_curso  quantidade_de_alunos
# 14     Análise de dados                    95
# 16  Internet das coisas                    81

# %% [markdown]
# ## Escrevendo no banco

# %%
muitas_matriculas.to_sql('muitas_matriculas', con=engine)

# %%
print(engine.table_names())
# Out:
# ['matriculas', 'muitas_matriculas']
# C:\Users\Renato\AppData\Local\Temp/ipykernel_11080/1043810782.py:1: SADeprecationWarning: The Engine.table_names() method is deprecated and will be removed in a future release.  Please refer to Inspector.get_table_names(). (deprecated since: 1.4)
#   print(engine.table_names())

# %%
matriculas_por_curso.head()
# Out:
#           quantidade_de_alunos          nome_do_curso
# id_curso
# 1                           50  Lógica de programação
# 2                           30          Java para Web
# 3                           12            C# para Web
# 4                            6          Ruby on Rails
# 5                           42       Cursos de Python

# %%
matriculas.head()
# Out:
#    id_aluno  id_curso
# 0       189        15
# 1       189         6
# 2       189        10
# 3        58        10
# 4        58         5

# %%
id_curso = 10
proxima_turma = matriculas.query("id_curso == {}".format(id_curso))

# %%
proxima_turma.head()
# Out:
#     id_aluno  id_curso
# 2        189        10
# 3         58        10
# 17         5        10
# 28       172        10
# 54       186        10

# %%
nomes.sample(3)
# Out:
#        nome  id_aluno                  dominio                          email  \
# 94     JAIR       289      @servicodoemail.com        jair@servicodoemail.com
# 79   MONICA       131  @dominiodoemmail.com.br  monica@dominiodoemmail.com.br
# 180    EDER        62  @dominiodoemmail.com.br    eder@dominiodoemmail.com.br
#
#      matriculas
# 94            1
# 79            1
# 180           4

# %%
proxima_turma.set_index('id_aluno').join(nomes.set_index('id_aluno'))
# Out:
#           id_curso       nome                  dominio  \
# id_aluno
# 5               10   PATRICIA  @dominiodoemmail.com.br
# 6               10   PRISCILA      @servicodoemail.com
# 18              10  ELIZABETE      @servicodoemail.com
# 22              10     RENATO      @servicodoemail.com
# 23              10  REGINALDO      @servicodoemail.com
# ...            ...        ...                      ...
# 376             10     RUBENS  @dominiodoemmail.com.br
# 388             10    RODRIGO      @servicodoemail.com
# 392             10    MATHEUS      @servicodoemail.com
# 397             10   EDIVALDO  @dominiodoemmail.com.br
# 398             10    EDILSON  @dominiodoemmail.com.br
#
#                                     email  matriculas
# id_aluno
# 5         patricia@dominiodoemmail.com.br           5
# 6             priscila@servicodoemail.com           2
# 18           elizabete@servicodoemail.com           8
# 22              renato@servicodoemail.com           2
# ...

# %%
proxima_turma.set_index('id_aluno').join(nomes.set_index('id_aluno'))['nome']
# Out:
# id_aluno
# 5       PATRICIA
# 6       PRISCILA
# 18     ELIZABETE
# 22        RENATO
# 23     REGINALDO
#          ...
# 376       RUBENS
# 388      RODRIGO
# 392      MATHEUS
# 397     EDIVALDO
# 398      EDILSON
# Name: nome, Length: 61, dtype: object

# %%
proxima_turma.set_index('id_aluno').join(nomes.set_index('id_aluno'))['nome'].to_frame()
# Out:
#                nome
# id_aluno
# 5          PATRICIA
# 6          PRISCILA
# 18        ELIZABETE
# 22           RENATO
# 23        REGINALDO
# ...             ...
# 376          RUBENS
# 388         RODRIGO
# 392         MATHEUS
# 397        EDIVALDO
# 398         EDILSON
#
# [61 rows x 1 columns]

# %%
nome_curso = cursos.loc[id_curso]
nome_curso
# Out:
# nome_do_curso    Código limpo com C#
# Name: 10, dtype: object

# %%
nome_curso = nome_curso.nome_do_curso
nome_curso
# Out:
# 'Código limpo com C#'

# %%
proxima_turma.rename(columns = {'nome':'Alunos do curso de {}'.format(nome_curso)})
# Out:
#      id_aluno  id_curso
# 2         189        10
# 3          58        10
# 17          5        10
# 28        172        10
# 54        186        10
# ..        ...       ...
# 746       206        10
# 773       208        10
# 779        62        10
# 789        82        10
# 803        50        10
#
# [61 rows x 2 columns]

# %%
proxima_turma = proxima_turma.rename(columns = {'nome':'Alunos do curso de {}'.format(nome_curso)})

# %% [markdown]
# ## exportando arquivos no formato Excel

# %%
proxima_turma.to_excel('proxima_turma.xlsx', index = False)

# %%
pd.read_excel('proxima_turma.xlsx')
# Out:
#     id_aluno  id_curso
# 0        189        10
# 1         58        10
# 2          5        10
# 3        172        10
# 4        186        10
# ..       ...       ...
# 56       206        10
# 57       208        10
# 58        62        10
# 59        82        10
# 60        50        10
#
# [61 rows x 2 columns]
