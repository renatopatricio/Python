# %% [markdown]
# ## Neste projeto iremos trabalhar a criação de estrutura de dados utilizando as Series e DataFrames

# %%
import pandas as pd

# %% [markdown]
# ## Series

# %% [markdown]
# #Aqui criaremos uma lista simples que contém uma sequência numérica de 1 à 5.

# %%
data=[1, 2, 3, 4, 5]

# %%
s=pd.Series(data)

# %%
s
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
index=["Linha" + str(i) for i in range(5)]

# %%
index
# Out:
# ['Linha0', 'Linha1', 'Linha2', 'Linha3', 'Linha4']

# %%
s = pd.Series(data=data, index=index)

# %%
s
# Out:
# Linha0    1
# Linha1    2
# Linha2    3
# Linha3    4
# Linha4    5
# dtype: int64

# %%
data={'Linha' + str(i):i+1 for i in range (5)}

# %%
data
# Out:
# {'Linha0': 1, 'Linha1': 2, 'Linha2': 3, 'Linha3': 4, 'Linha4': 5}

# %%
s=pd.Series(data)
s
# Out:
# Linha0    1
# Linha1    2
# Linha2    3
# Linha3    4
# Linha4    5
# dtype: int64

# %%
s1=s+2

# %%
s1
# Out:
# Linha0    3
# Linha1    4
# Linha2    5
# Linha3    6
# Linha4    7
# dtype: int64

# %%
s2=s+s1

# %%
s2
# Out:
# Linha0     4
# Linha1     6
# Linha2     8
# Linha3    10
# Linha4    12
# dtype: int64

# %% [markdown]
# ## DataFrame

# %% [markdown]
# #Aqui faremos uma nova lista numérica, na verdade, uma lista que contém outras listas.

# %%
data=[[1,2,3],[4,5,6],[7,8,9]]

# %%
data
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %%
df1=pd.DataFrame(data=data)

# %%
df1
# Out:
#    0  1  2
# 0  1  2  3
# 1  4  5  6
# 2  7  8  9

# %%
lista1=pd.DataFrame(data=data)

# %%
lista1
# Out:
#    0  1  2
# 0  1  2  3
# 1  4  5  6
# 2  7  8  9

# %%
df1=pd.DataFrame(data=data)

# %%
df1
# Out:
#    0  1  2
# 0  1  2  3
# 1  4  5  6
# 2  7  8  9

# %%
index=['Coluna'+str(i) for i in range(3)]
index
# Out:
# ['Coluna0', 'Coluna1', 'Coluna2']

# %%
index=['Linha'+str(i) for i in range(3)]
index
# Out:
# ['Linha0', 'Linha1', 'Linha2']

# %%
df1=pd.DataFrame(data=data, index=index)
index
# Out:
# ['Linha0', 'Linha1', 'Linha2']

# %%
df1=pd.DataFrame(data=data, index=index)
df1
# Out:
#         0  1  2
# Linha0  1  2  3
# Linha1  4  5  6
# Linha2  7  8  9

# %%
columns=['Coluna'+str(i) for i in range(3)]
columns
# Out:
# ['Coluna0', 'Coluna1', 'Coluna2']

# %%
df1=pd.DataFrame(data=data, index=index, columns=columns)
df1
# Out:
#         Coluna0  Coluna1  Coluna2
# Linha0        1        2        3
# Linha1        4        5        6
# Linha2        7        8        9

# %%
data = {'Coluna0': {'Linha0': 1, 'Linha1': 4, 'Linha2': 7},
        'Coluna1': {'Linha0': 2, 'Linha1': 5, 'Linha2': 8},
        'Coluna2': {'Linha0': 3, 'Linha1': 6, 'Linha2': 9}}
data
# Out:
# {'Coluna0': {'Linha0': 1, 'Linha1': 4, 'Linha2': 7},
#  'Coluna1': {'Linha0': 2, 'Linha1': 5, 'Linha2': 8},
#  'Coluna2': {'Linha0': 3, 'Linha1': 6, 'Linha2': 9}}

# %%
df2=pd.DataFrame(data=data, index=index, columns=columns)
df2
# Out:
#         Coluna0  Coluna1  Coluna2
# Linha0        1        2        3
# Linha1        4        5        6
# Linha2        7        8        9

# %%
data=[(1,2,3),(4,5,6),(7,8,9)]
data
# Out:
# [(1, 2, 3), (4, 5, 6), (7, 8, 9)]

# %%
df3=pd.DataFrame(data=data, index=index, columns=columns)
df3
# Out:
#         Coluna0  Coluna1  Coluna2
# Linha0        1        2        3
# Linha1        4        5        6
# Linha2        7        8        9

# %%
df1[df1>0]='A'
df1
# Out:
#        Coluna0 Coluna1 Coluna2
# Linha0       A       A       A
# Linha1       A       A       A
# Linha2       A       A       A

# %%
df2[df2>0]='B'
df2
# Out:
#        Coluna0 Coluna1 Coluna2
# Linha0       B       B       B
# Linha1       B       B       B
# Linha2       B       B       B

# %%
df3[df3>0]='C'
df3
# Out:
#        Coluna0 Coluna1 Coluna2
# Linha0       C       C       C
# Linha1       C       C       C
# Linha2       C       C       C

# %% [markdown]
# ## Concatenação

# %% [markdown]
# #Aqui iremos acionar a ferramenta concat() do Pandas, que como indica o nome, realiza concatenações

# %%
df4=pd.concat([df1,df2,df3])
df4
# Out:
#        Coluna0 Coluna1 Coluna2
# Linha0       A       A       A
# Linha1       A       A       A
# Linha2       A       A       A
# Linha0       B       B       B
# Linha1       B       B       B
# Linha2       B       B       B
# Linha0       C       C       C
# Linha1       C       C       C
# Linha2       C       C       C

# %% [markdown]
# ## Concatenação de tabelas por linhas

# %%
df4=pd.concat([df1,df2,df3], axis=1)
df4
# Out:
#        Coluna0 Coluna1 Coluna2 Coluna0 Coluna1 Coluna2 Coluna0 Coluna1 Coluna2
# Linha0       A       A       A       B       B       B       C       C       C
# Linha1       A       A       A       B       B       B       C       C       C
# Linha2       A       A       A       B       B       B       C       C       C
